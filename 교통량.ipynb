# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeeungJ/PythonProject2024-1/blob/main/%EA%B5%90%ED%86%B5%EB%9F%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#설치후 세션 다시시작
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 44s (236 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121913 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# ...

# %%
import pandas as pd
traffic=pd.read_excel('TrafficVolume(ZONE).xlsx',header=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
traffic.loc[7,3:]=traffic.loc[8,3:]

# %%
traffic.drop(8, inplace=True)

# %%
traffic.columns=traffic.loc[7]

# %%
traffic.drop(index=range(7), inplace=True)

# %%
traffic.drop(7, inplace=True)

# %%
traffic.reset_index(drop=True,inplace=True)

# %%
traffic_all = traffic.iloc[:, :28]

# %%
traffic_all.iloc[0:,3:] = traffic_all.iloc[:,3:].astype(int)
# Out:
# <ipython-input-146-1df258de52dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traffic_all.iloc[0:,3:] = traffic_all.iloc[:,3:].astype(int)

# %%
traffic_all
# Out:
# 7    ZONE ID     시도   시군구     전일   1시   2시   3시   4시   5시   6시  ...   15시  \
# 0   11010000  서울특별시   종로구  13265  177  129   98   89  133  296  ...   722
# 1   11020000  서울특별시    중구  13763  191  134  105   92  124  279  ...   763
# 2   11030000  서울특별시   용산구  19941  311  234  179  160  246  535  ...  1098
# 3   11040000  서울특별시   성동구  19823  294  232  175  170  278  581  ...  1106
# 4   11050000  서울특별시   광진구  19525  266  195  151  143  224  499  ...  1063
# 5   11060000  서울특별시  동대문구  12464  170  120   92   88  145  327  ...   672
# 6   11070000  서울특별시   중랑구  13339  184  138  102  103  177  408  ...   712
# 7   11080000  서울특별시   성북구  13363  194  144  110  112  183  415  ...   706
# 8   11090000  서울특별시   강북구   9648  126   87   71   68  104  253  ...   527
# 9   11100000  서울특별시   도봉구   9435  121   84   66   68  111  263  ...   506
# 10  11110000  서울특별시   노원구  12554  171  129   99  102  173  399  ...   676
# 11  11120000  서울특별시   은평구   9922  130   91   71   69  106  258  ...   521
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.rc('font', family='NanumGothic')
plt.bar(traffic_all['시군구'], traffic_all['전일'])
plt.xlabel('시군구')
plt.ylabel('교통량')
plt.title('시군구별 교통량')
plt.xticks(rotation=90)  # x축 라벨을 90도 회전하여 표시
plt.tight_layout()
plt.show()

# %%
import requests
import geopandas as gpd
import folium
import json

state_geo = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'
response = requests.get(state_geo)
geo_data = response.json()

# GeoDataFrame으로 변환
geo_df = gpd.GeoDataFrame.from_features(geo_data['features'])

# GeoJSON 파일의 열 이름 확인
print(geo_df.columns)

# 교통량 데이터를 GeoDataFrame에 병합 ('name' 열 이름 사용)
geo_df = geo_df.merge(traffic_all, left_on='name', right_on='시군구')

seoul_location = [37.5665, 126.9780]

m = folium.Map(location=seoul_location, zoom_start=10, tiles='Stamen Toner', attr='© OpenStreetMap contributors',zoom_control=False)
folium.GeoJson(
    geo_data,
    name='서울 외 지역',
    style_function=lambda x: {'color': '#cccccc', 'fillOpacity': 0}
).add_to(m)

# Choropleth Layer 추가
folium.Choropleth(
    geo_data=geo_data,  # GeoJSON 데이터 사용
    name='choropleth',
    data=geo_df,  # 병합된 GeoDataFrame 사용
    columns=['시군구', '전일'],
    key_on='feature.properties.name',  # 'name' 속성을 사용하여 매핑
    fill_color='Blues',
    fill_opacity=0.5,
    line_opacity=0.5,
    legend_name='교통량'
).add_to(m)


for idx, row in geo_df.iterrows():
    folium.Marker(
        location=[row['geometry'].centroid.y, row['geometry'].centroid.x],
        icon=folium.DivIcon(html=f'<div style="font-size: 10pt; color: black; writing-mode: horizontal-tb;">{row["시군구"]}</div>')
    ).add_to(m)


# 지도 출력
m
# Out:
# Index(['geometry', 'code', 'name', 'name_eng', 'base_year'], dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import requests
import geopandas as gpd
import folium
import json

state_geo = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'
response = requests.get(state_geo)
geo_data = response.json()

# GeoDataFrame으로 변환
geo_df = gpd.GeoDataFrame.from_features(geo_data['features'])

# GeoJSON 파일의 열 이름 확인
print(geo_df.columns)

# 교통량 데이터를 GeoDataFrame에 병합 ('name' 열 이름 사용)
geo_df = geo_df.merge(traffic_all, left_on='name', right_on='시군구')

seoul_location = [37.5665, 126.9780]

m = folium.Map(location=seoul_location, zoom_start=10, tiles='Stamen Toner', attr='© OpenStreetMap contributors',zoom_control=False)
folium.GeoJson(
    geo_data,
    name='서울 외 지역',
    style_function=lambda x: {'color': '#cccccc', 'fillOpacity': 0.3}
).add_to(m)

# Choropleth Layer 추가
folium.Choropleth(
    geo_data=geo_data,  # GeoJSON 데이터 사용
    name='choropleth',
    data=geo_df,  # 병합된 GeoDataFrame 사용
    columns=['시군구', '전일'],
    key_on='feature.properties.name',  # 'name' 속성을 사용하여 매핑
    fill_color='Blues',
    fill_opacity=0.5,
    line_opacity=0.5,
    legend_name='교통량'
).add_to(m)

# 각 지역 위에 지역명 표시
for idx, row in geo_df.iterrows():
    folium.Marker(
        location=[row['geometry'].centroid.y, row['geometry'].centroid.x],
        icon=None,
        popup=row['시군구'],
    ).add_to(m)

# 지도 출력
m
# Out:
# Index(['geometry', 'code', 'name', 'name_eng', 'base_year'], dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
traffic_1=traffic_all[['시군구','전일']]
traffic_1
# Out:
# 7    시군구     전일
# 0    종로구  13265
# 1     중구  13763
# 2    용산구  19941
# 3    성동구  19823
# 4    광진구  19525
# 5   동대문구  12464
# 6    중랑구  13339
# 7    성북구  13363
# 8    강북구   9648
# 9    도봉구   9435
# 10   노원구  12554
# 11   은평구   9922
# 12  서대문구  15659
# 13   마포구  19833
# 14   양천구  15458
# 15   강서구  15365
# 16   구로구  11458
# 17   금천구  15619
# 18  영등포구  18443
# 19   동작구  17236
# 20   관악구  15705
# 21   서초구  21447
# 22   강남구  18704
# 23   송파구  17447
# 24   강동구  18823

# %%
traffic
# Out:
# 7    ZONE ID     시도   시군구     전일   1시   2시   3시   4시   5시   6시  ...  15시  16시  \
# 0   11010000  서울특별시   종로구  13265  177  129   98   89  133  296  ...   83   80
# 1   11020000  서울특별시    중구  13763  191  134  105   92  124  279  ...   75   77
# 2   11030000  서울특별시   용산구  19941  311  234  179  160  246  535  ...  116  110
# 3   11040000  서울특별시   성동구  19823  294  232  175  170  278  581  ...  118  117
# 4   11050000  서울특별시   광진구  19525  266  195  151  143  224  499  ...  119  116
# 5   11060000  서울특별시  동대문구  12464  170  120   92   88  145  327  ...   83   84
# 6   11070000  서울특별시   중랑구  13339  184  138  102  103  177  408  ...   93   92
# 7   11080000  서울특별시   성북구  13363  194  144  110  112  183  415  ...   89   87
# 8   11090000  서울특별시   강북구   9648  126   87   71   68  104  253  ...   62   62
# 9   11100000  서울특별시   도봉구   9435  121   84   66   68  111  263  ...   69   66
# 10  11110000  서울특별시   노원구  12554  171  129   99  102  173  399  ...   98   97
# ...

# %%
drop_col=['ZONE ID','시도','전일']
traffic_hour=traffic_all.drop(columns=drop_col)

# %%
traffic_hour
# Out:
# 7    시군구   1시   2시   3시   4시   5시   6시    7시    8시    9시  ...   15시   16시  \
# 0    종로구  177  129   98   89  133  296   595   844   888  ...   722   744
# 1     중구  191  134  105   92  124  279   566   844   927  ...   763   782
# 2    용산구  311  234  179  160  246  535   905  1154  1228  ...  1098  1108
# 3    성동구  294  232  175  170  278  581   931  1132  1168  ...  1106  1130
# 4    광진구  266  195  151  143  224  499   903  1192  1226  ...  1063  1105
# 5   동대문구  170  120   92   88  145  327   560   802   858  ...   672   694
# 6    중랑구  184  138  102  103  177  408   692   862   878  ...   712   741
# 7    성북구  194  144  110  112  183  415   665   839   849  ...   706   725
# 8    강북구  126   87   71   68  104  253   452   611   655  ...   527   550
# 9    도봉구  121   84   66   68  111  263   430   606   673  ...   506   526
# 10   노원구  171  129   99  102  173  399   608   801   838  ...   676   692
# 11   은평구  130   91   71   69  106  258   489   671   691  ...   521   538
# ...

# %%
import matplotlib.pyplot as plt

traffic_hour.set_index('시군구', inplace=True)

# 그래프 크기 설정
plt.figure(figsize=(14, 8))

# 각 시군구별로 선 그래프를 그림
for index, row in traffic_hour.iterrows():
    plt.plot(row.index, row.values, label=index)

# 그래프 제목 및 축 레이블 설정
plt.title('시군구별 시간대별 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 범례 추가
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))

# 그래프 표시
plt.show()

# %%
region_hour = traffic_hour.T
region_hour
# Out:
# 시군구  종로구   중구   용산구   성동구   광진구 동대문구  중랑구  성북구  강북구  도봉구  ...  강서구  구로구   금천구  \
# 7                                                         ...
# 1시   177  191   311   294   266  170  184  194  126  121  ...  189  160   192
# 2시   129  134   234   232   195  120  138  144   87   84  ...  147  114   146
# 3시    98  105   179   175   151   92  102  110   71   66  ...  113   87   112
# 4시    89   92   160   170   143   88  103  112   68   68  ...  120   84   121
# 5시   133  124   246   278   224  145  177  183  104  111  ...  215  137   208
# 6시   296  279   535   581   499  327  408  415  253  263  ...  468  325   475
# 7시   595  566   905   931   903  560  692  665  452  430  ...  768  543   793
# 8시   844  844  1154  1132  1192  802  862  839  611  606  ...  964  738  1033
# 9시   888  927  1228  1168  1226  858  878  849  655  673  ...  993  775  1040
# 10시  751  773  1100  1075  1072  712  752  744  535  533  ...  861  645   908
# ...

# %%
import matplotlib.pyplot as plt

region = input("지역을 입력하세요: ")
# 주어진 데이터
data = region_hour[region].astype('int')

plt.figure(figsize=(14, 8))
# 막대그래프 생성
plt.bar(data.index, data, color='skyblue')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 그래프 표시
plt.grid(True, axis='y')
plt.show()
# Out:
# 지역을 입력하세요: 구로구

# %%
traffic_car=traffic.iloc[:,29:53]
traffic_car=pd.concat([traffic.iloc[:,2:3],traffic_car], axis=1)
traffic_car
# Out:
# 7    시군구   1시   2시   3시   4시   5시   6시   7시    8시    9시  ...  15시   16시   17시  \
# 0    종로구  158  117   86   74  106  236  486   728   773  ...  612   638   700
# 1     중구  170  120   92   77   98  217  453   722   806  ...  655   673   745
# 2    용산구  279  208  153  131  197  426  759  1007  1082  ...  955   971  1029
# 3    성동구  265  208  148  138  226  473  785   989  1034  ...  967   991  1047
# 4    광진구  233  170  125  113  178  407  750  1028  1068  ...  911   955  1023
# 5   동대문구  149  107   79   72  117  265  462   693   749  ...  563   584   653
# 6    중랑구  158  119   84   81  137  323  564   726   749  ...  595   625   689
# 7    성북구  171  128   94   93  149  345  557   722   733  ...  597   618   665
# 8    강북구  108   77   63   57   80  204  365   521   563  ...  439   461   512
# 9    도봉구  105   73   56   54   86  212  347   514   573  ...  416   438   497
# 10   노원구  146  110   80   78  131  313  490   680   710  ...  557   574   629
# ...

# %%
car_hour = traffic_car.T
car_hour.columns=car_hour.iloc[0]
car_hour = car_hour.drop(car_hour.index[0])
car_hour
# Out:
# 시군구  종로구   중구   용산구   성동구   광진구 동대문구  중랑구  성북구  강북구  도봉구  ...  강서구  구로구  금천구  \
# 7                                                         ...
# 1시   158  170   279   265   233  149  158  171  108  105  ...  161  142  167
# 2시   117  120   208   208   170  107  119  128   77   73  ...  125  101  127
# 3시    86   92   153   148   125   79   84   94   63   56  ...   91   74   92
# 4시    74   77   131   138   113   72   81   93   57   54  ...   95   68   95
# 5시   106   98   197   226   178  117  137  149   80   86  ...  171  109  164
# 6시   236  217   426   473   407  265  323  345  204  212  ...  375  267  386
# 7시   486  453   759   785   750  462  564  557  365  347  ...  639  446  640
# 8시   728  722  1007   989  1028  693  726  722  521  514  ...  826  632  872
# 9시   773  806  1082  1034  1068  749  749  733  563  573  ...  859  670  881
# 10시  632  659   953   943   913  595  617  625  443  431  ...  725  538  748
# ...

# %%
import matplotlib.pyplot as plt

region=input()
# 주어진 데이터
data = car_hour[region].astype('int')

plt.figure(figsize=(14, 8))
# 그래프 생성
plt.plot(data, marker='o', linestyle='-')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 승용차 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 그래프 표시
plt.grid(True)
plt.show()
# Out:
# 구로구

# %%
import matplotlib.pyplot as plt

region = input("지역을 입력하세요: ")

# 주어진 데이터
data_region_hour = region_hour[region].astype('int')
data_car_hour = car_hour[region].astype('int')

plt.figure(figsize=(14, 8))

# 막대그래프 생성
plt.bar(data_region_hour.index, data_region_hour, color='skyblue', label='전체 교통량')

# 꺾은선 그래프 생성
plt.plot(data_car_hour, marker='o', linestyle='-', color='orange', label='승용차 교통량')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 범례 추가
plt.legend()

# 그래프 표시
plt.grid(True, axis='y')
plt.show()
# Out:
# 지역을 입력하세요: 구로구

# %%
traffic_bus=traffic.iloc[:,54:78]
traffic_bus=pd.concat([traffic.iloc[:,2:3],traffic_bus], axis=1)
traffic_bus
# Out:
# 7    시군구  1시 2시 3시 4시 5시  6시  7시  8시  9시  ... 15시 16시 17시 18시 19시 20시 21시 22시  \
# 0    종로구   7  3  2  2  5  15  26  31  29  ...  27  26  26  26  26  23  21  21
# 1     중구   8  3  2  2  5  17  32  37  38  ...  33  32  31  32  32  29  27  25
# 2    용산구   6  2  2  2  5  16  28  32  31  ...  27  27  27  27  27  23  21  20
# 3    성동구   5  2  2  2  6  15  22  24  23  ...  21  22  22  22  21  16  15  14
# 4    광진구   8  3  2  2  7  18  33  37  36  ...  33  34  34  35  35  31  27  24
# 5   동대문구   8  2  2  2  7  17  27  31  29  ...  26  26  26  27  26  22  21  20
# 6    중랑구   8  3  2  2  8  15  24  28  26  ...  24  24  24  25  24  21  19  18
# 7    성북구   7  2  2  2  7  14  21  23  23  ...  20  20  20  20  20  17  16  15
# 8    강북구   9  3  1  2  8  16  27  29  28  ...  26  27  26  26  26  22  22  21
# 9    도봉구   7  3  2  2  6  13  21  24  24  ...  21  22  21  22  21  18  17  16
# 10   노원구   7  2  2  2  7  14  22  24  23  ...  21  21  21  23  22  16  15  13
# ...

# %%
bus_hour = traffic_bus.T
bus_hour.columns=bus_hour.iloc[0]
bus_hour = bus_hour.drop(bus_hour.index[0])
bus_hour
# Out:
# 시군구 종로구  중구 용산구 성동구 광진구 동대문구 중랑구 성북구 강북구 도봉구  ... 강서구 구로구 금천구 영등포구 동작구 관악구  \
# 7                                             ...
# 1시    7   8   6   5   8    8   8   7   9   7  ...   6   6   6    7   6   7
# 2시    3   3   2   2   3    2   3   2   3   3  ...   2   2   2    2   2   2
# 3시    2   2   2   2   2    2   2   2   1   2  ...   2   2   1    2   2   2
# 4시    2   2   2   2   2    2   2   2   2   2  ...   2   2   2    2   2   3
# 5시    5   5   5   6   7    7   8   7   8   6  ...   6   6   6    6   6   7
# 6시   15  17  16  15  18   17  15  14  16  13  ...  14  13  15   16  15  17
# 7시   26  32  28  22  33   27  24  21  27  21  ...  22  22  26   26  28  30
# 8시   31  37  32  24  37   31  28  23  29  24  ...  28  24  28   30  30  32
# 9시   29  38  31  23  36   29  26  23  28  24  ...  24  22  27   28  28  33
# 10시  27  35  28  22  34   27  25  21  27  22  ...  22  22  26   26  26  30
# 11시  26  33  26  20  33   25  24  19  26  20  ...  21  21  24   24  25  29
# ...

# %%
import matplotlib.pyplot as plt

region=input()
# 주어진 데이터
data = bus_hour[region].astype('int')

plt.figure(figsize=(14, 8))
# 그래프 생성
plt.plot(data, marker='o', linestyle='-')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 버스 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 그래프 표시
plt.grid(True)
plt.show()
# Out:
# 구로구

# %%
import matplotlib.pyplot as plt

region = input("지역을 입력하세요: ")

# 주어진 데이터
data_region_hour = region_hour[region].astype('int')
data_car_hour = car_hour[region].astype('int')
data_bus_hour = bus_hour[region].astype('int')

plt.figure(figsize=(14, 8))

# 막대그래프 생성
plt.bar(data_region_hour.index, data_region_hour, color='skyblue', label='전체 교통량')

# 꺾은선 그래프 생성
plt.plot(data_car_hour, marker='o', linestyle='-', color='orange', label='승용차 교통량')
plt.plot(data_bus_hour, marker='o', linestyle='-', color='green', label='버스 교통량')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 범례 추가
plt.legend()

# 그래프 표시
plt.grid(True, axis='y')
plt.show()
# Out:
# 지역을 입력하세요: 구로구

# %%
traffic_truck=traffic.iloc[:,79:103]
traffic_truck=pd.concat([traffic.iloc[:,2:3],traffic_truck], axis=1)
traffic_truck
# Out:
# 7    시군구  1시  2시  3시  4시  5시   6시   7시   8시   9시  ...  15시  16시  17시  18시  \
# 0    종로구  12   9  10  13  22   45   83   85   86  ...   83   80   75   72
# 1     중구  13  11  11  13  21   45   81   85   83  ...   75   77   75   68
# 2    용산구  26  24  24  27  44   93  118  115  115  ...  116  110  105   97
# 3    성동구  24  22  25  30  46   93  124  119  111  ...  118  117  112  104
# 4    광진구  25  22  24  28  39   74  120  127  122  ...  119  116  116  111
# 5   동대문구  13  11  11  14  21   45   71   78   80  ...   83   84   82   76
# 6    중랑구  18  16  16  20  32   70  104  108  103  ...   93   92   91   84
# 7    성북구  16  14  14  17  27   56   87   94   93  ...   89   87   86   83
# 8    강북구   9   7   7   9  16   33   60   61   64  ...   62   62   61   56
# 9    도봉구   9   8   8  12  19   38   62   68   76  ...   69   66   67   62
# 10   노원구  18  17  17  22  35   72   96   97  105  ...   98   97   93   88
# 11   은평구   9   8   8  11  19   34   65   73   77  ...   66   63   63   61
# ...

# %%
truck_hour = traffic_truck.T
truck_hour.columns=truck_hour.iloc[0]
truck_hour = truck_hour.drop(truck_hour.index[0])
truck_hour
# Out:
# 시군구 종로구  중구  용산구  성동구  광진구 동대문구  중랑구 성북구 강북구 도봉구  ...  강서구 구로구  금천구 영등포구  동작구  \
# 7                                                 ...
# 1시   12  13   26   24   25   13   18  16   9   9  ...   22  12   19   29   24
# 2시    9  11   24   22   22   11   16  14   7   8  ...   20  11   17   23   19
# 3시   10  11   24   25   24   11   16  14   7   8  ...   20  11   19   24   22
# 4시   13  13   27   30   28   14   20  17   9  12  ...   23  14   24   30   25
# 5시   22  21   44   46   39   21   32  27  16  19  ...   38  22   38   46   42
# 6시   45  45   93   93   74   45   70  56  33  38  ...   79  45   74   94   81
# 7시   83  81  118  124  120   71  104  87  60  62  ...  107  75  127  129  107
# 8시   85  85  115  119  127   78  108  94  61  68  ...  110  82  133  126  104
# 9시   86  83  115  111  122   80  103  93  64  76  ...  110  83  132  125  101
# 10시  92  79  119  110  125   90  110  98  65  80  ...  114  85  134  130  102
# ...

# %%
import matplotlib.pyplot as plt

region=input()
# 주어진 데이터
data = truck_hour[region].astype('int')

plt.figure(figsize=(14, 8))
# 그래프 생성
plt.plot(data, marker='o', linestyle='-')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 트럭 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 그래프 표시
plt.grid(True)
plt.show()
# Out:
# 구로구

# %%
import matplotlib.pyplot as plt

region = input("지역을 입력하세요: ")

# 주어진 데이터
data_region_hour = region_hour[region].astype('int')
data_car_hour = car_hour[region].astype('int')
data_bus_hour = bus_hour[region].astype('int')
data_truck_hour = truck_hour[region].astype('int')

plt.figure(figsize=(14, 8))

# 막대그래프 생성
plt.bar(data_region_hour.index, data_region_hour, color='skyblue', label='전체 교통량')

# 꺾은선 그래프 생성
plt.plot(data_car_hour, marker='o', linestyle='-', color='orange', label='승용차 교통량')
plt.plot(data_bus_hour, marker='o', linestyle='-', color='green', label='버스 교통량')
plt.plot(data_truck_hour, marker='o', linestyle='-', color='blue', label='트럭 교통량')

# 그래프 제목과 축 레이블 추가
plt.title(f'{region} 시간대별 교통량')
plt.xlabel('시간')
plt.ylabel('교통량')

# 범례 추가
plt.legend()

# 그래프 표시
plt.grid(True, axis='y')
plt.show()
# Out:
# 지역을 입력하세요: 구로구

# %%
accident=pd.read_csv('/content/시간대별+교통사고+현황_2022.csv',header=None)
accident.drop(0,inplace=True)
accident.drop(1,inplace=True)
accident.columns=accident.loc[2]
accident.reset_index(drop=True,inplace=True)
accident_1=accident[accident['항목']=='발생건수']
accident_1=accident_1.iloc[:,1:]
accident_1.reset_index(drop=True,inplace=True)
accident_1.drop(0,inplace=True)
accident_1.reset_index(drop=True,inplace=True)
accident_1
# Out:
# 2  자치구별(2)    항목    소계 00시-02시 02시-04시 04시-06시 06시-08시 08시-10시 10시-12시  \
# 0      종로구  발생건수   974      44      26      25      42     101      94
# 1       중구  발생건수   943      54      27      29      39      92      93
# 2      용산구  발생건수  1014      36      47      38      47      76     110
# 3      성동구  발생건수   948      55      21      29      40      94      95
# 4      광진구  발생건수   708      41      26      22      24      69      55
# 5     동대문구  발생건수  1534      61      28      26      79     169     184
# 6      중랑구  발생건수  1401      61      22      38      57     122     128
# 7      성북구  발생건수  1288      60      34      32      77     127     123
# 8      강북구  발생건수  1044      40      36      20      44      96     103
# 9      도봉구  발생건수   522      23      13      18      18      48      41
# 10     노원구  발생건수  1384      55      33      27      72     148     140
# 11     은평구  발생건수   918      36      20      22      39      86      87
# ...

# %%
traffic_all
# Out:
# 7    ZONE ID     시도   시군구     전일   1시   2시   3시   4시   5시   6시  ...   15시  \
# 0   11010000  서울특별시   종로구  13265  177  129   98   89  133  296  ...   722
# 1   11020000  서울특별시    중구  13763  191  134  105   92  124  279  ...   763
# 2   11030000  서울특별시   용산구  19941  311  234  179  160  246  535  ...  1098
# 3   11040000  서울특별시   성동구  19823  294  232  175  170  278  581  ...  1106
# 4   11050000  서울특별시   광진구  19525  266  195  151  143  224  499  ...  1063
# 5   11060000  서울특별시  동대문구  12464  170  120   92   88  145  327  ...   672
# 6   11070000  서울특별시   중랑구  13339  184  138  102  103  177  408  ...   712
# 7   11080000  서울특별시   성북구  13363  194  144  110  112  183  415  ...   706
# 8   11090000  서울특별시   강북구   9648  126   87   71   68  104  253  ...   527
# 9   11100000  서울특별시   도봉구   9435  121   84   66   68  111  263  ...   506
# 10  11110000  서울특별시   노원구  12554  171  129   99  102  173  399  ...   676
# 11  11120000  서울특별시   은평구   9922  130   91   71   69  106  258  ...   521
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 교통량 데이터 불러오기
traffic_data = traffic_all.copy()

# 2시간 단위로 교통량 데이터 합산
traffic_data_hourly = pd.DataFrame()
time_intervals = [(i, i+1) for i in range(0, 24, 2)]

for start, end in time_intervals:
    col_name = f'{start}시-{end+1}시'
    traffic_data_hourly[col_name] = traffic_data.iloc[:, 4+start] + traffic_data.iloc[:, 4+end]

# 자치구를 포함하여 데이터프레임 구성
traffic_data_hourly['자치구'] = traffic_data['시군구']

# 사고량 데이터 불러오기
accident_data = accident_1.copy()

# 교통량과 사고량 데이터의 자치구 순서를 맞추기 위해 인덱스 재설정
accident_data_reordered = accident_data.set_index('자치구별(2)').reindex(traffic_data['시군구']).reset_index()

# 데이터 타입 점검 및 변환
traffic_data_hourly.drop(columns='자치구', inplace=True)
traffic_data_hourly = traffic_data_hourly.apply(pd.to_numeric, errors='coerce')

accident_data_reordered['소계'] = pd.to_numeric(accident_data_reordered['소계'], errors='coerce')

# 교통량과 사고량 간의 상관관계 계산
correlation = traffic_data_hourly.corrwith(accident_data_reordered['소계'])

# 상관관계 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation.index, y=correlation.values)
plt.title('교통량과 사고 발생 건수의 상관관계')
plt.xlabel('시간대')
plt.ylabel('상관관계')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# 교통량 데이터
traffic_data = traffic_all[['시군구', '전일']]
traffic_data.columns = ['시군구', '교통량']  # 컬럼명을 변경합니다.

# 사고량 데이터
accident_data = accident_1[['자치구별(2)', '소계']]
accident_data.columns = ['시군구', '사고량']  # 컬럼명을 변경합니다.

# 데이터프레임 병합
df_merged = pd.merge(traffic_data, accident_data, on='시군구')

# 교통량과 사고량 간의 상관관계 계산
correlation = df_merged['교통량'].astype('int').corr(df_merged['사고량'].astype('int'))

# 결과 출력
print("교통량과 사고량 간의 상관관계:", correlation)
# Out:
# 교통량과 사고량 간의 상관관계: 0.34174099883876324

# %%
traffic_all.to_excel('traffic_all.xlsx',index=False)

# %%
accident_1.to_excel('accident_1.xlsx',index=False)
