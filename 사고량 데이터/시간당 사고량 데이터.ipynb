# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
acc = pd.read_csv('시간대별+교통사고+현황_2022.csv')
plt.rcParams.update({'font.family':'Malgun Gothic'})
acc.sort_values('자치구별(2)')
# Out:
#    자치구별(1) 자치구별(2)    항목  2022 2022.1 2022.2 2022.3 2022.4 2022.5 2022.6  \
# 73      합계     강남구  부상자수  5052    301    226    150    183    380    484
# 72      합계     강남구  사망자수    16      3      2      -      2      1      -
# 71      합계     강남구  발생건수  3709    206    141    103    132    292    356
# 79      합계     강동구  부상자수  1553     77     33     42     98    144    142
# 77      합계     강동구  발생건수  1151     51     23     35     70    104    110
# ..     ...     ...   ...   ...    ...    ...    ...    ...    ...    ...
# 9       합계      중구  사망자수     2      -      -      -      -      -      -
# 8       합계      중구  발생건수   943     54     27     29     39     92     93
# 25      합계     중랑구  부상자수  1890     90     34     52     73    150    168
# 24      합계     중랑구  사망자수    10      2      1      -      1      -      2
# 23      합계     중랑구  발생건수  1401     61     22     38     57    122    128
#
#    2022.7 2022.8 2022.9 2022.10 2022.11 2022.12
# ...

# %%
place = input("자치구를 입력하세요 : ")
acc_gangnam = acc.query('`자치구별(2)`==@place')\
                .transpose()\
                .iloc[4:]
acc_gangnam.columns=['발생건수','사망자수','부상자수']
acc_gangnam.drop(columns = '사망자수', inplace = True)
acc_gangnam.index = [f"{str(i*2).zfill(2)}시" for i in range(1, 13)]

acc_gangnam = acc_gangnam.astype({'발생건수' : int, "부상자수" : int})
sns.lineplot(data = acc_gangnam, dashes = False)
plt.title(f'{place} 시간대별 사고량')
plt.plot(marker='o')
plt.figure(figsize=(14, 8))
# Out:
# 자치구를 입력하세요 :  중구
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
