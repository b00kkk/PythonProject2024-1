# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
age = pd.read_csv('가해운전자+연령대별+교통사고+현황_2022.csv')
plt.rcParams.update({'font.family':'Malgun Gothic'})
age
# Out:
#     자치구별(1)  자치구별(2)        항목   2022 2022.1  2022.2  2022.3  2022.4  2022.5  \
# 0   자치구별(1)  자치구별(2)        항목     합계     합계      합계      합계      합계      합계
# 1   자치구별(1)  자치구별(2)        항목     소계  20세이하  21~30세  31~40세  41~50세  51~60세
# 2         계       소계  발생건수 (건)  33698    968    4378    5422    5709    7323
# 3         계       소계  부상자수 (명)  45329   1272    6115    7461    7701    9707
# 4         계      종로구  발생건수 (건)    974     15     105     149     145     241
# 5         계      종로구  부상자수 (명)   1351     19     143     211     208     329
# 6         계       중구  발생건수 (건)    943     14      97     164     161     218
# 7         계       중구  부상자수 (명)   1212     18     122     209     208     285
# 8         계      용산구  발생건수 (건)   1014     22     133     183     176     200
# 9         계      용산구  부상자수 (명)   1330     26     196     242     219     245
# 10        계      성동구  발생건수 (건)    948     35     145     164     143     191
# ...

# %%
place = input()
age1 = age.query('`자치구별(2)`== @place')\
            .transpose()\
            .iloc[4:]
age1.columns = ['발생건수','부상자수']
age1.index = ['20세 이하','21~30세','31~40세','41~50세','51~60세','61~64세','65세이상','연령불명']
age1 = age1.astype({'발생건수' : int , '부상자수' : int})
age1.plot.barh()
plt.title(f'{place} 연령대별 사고량')
# Out:
#  송파구
# <Axes: >

# %%
sns.barplot(x = '발생건수'
